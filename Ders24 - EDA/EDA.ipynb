# %%
import pandas_datareader as pdr 
import pandas as pd

# %%
df_tesla = pdr.get_data_yahoo('TSLA')
# pd.read_csv('kutphane.csv')
type(df_tesla)
# Out:
# pandas.core.frame.DataFrame

# %%
df_tesla.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2022-02-23  835.299988  760.559998  830.429993  764.039978  31752300.0
# 2022-02-24  802.479980  700.000000  700.390015  800.770020  45107400.0
# 2022-02-25  819.500000  782.400024  809.229980  809.869995  25309500.0
# 2022-02-28  876.859985  814.710022  815.010010  870.429993  32877700.0
# 2022-03-01  889.880005  856.695190  869.679993  869.219421  16528666.0
#
#              Adj Close
# Date
# 2022-02-23  764.039978
# 2022-02-24  800.770020
# 2022-02-25  809.869995
# 2022-02-28  870.429993
# 2022-03-01  869.219421

# %%
df_tesla.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['High'].plot(figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['High'].plot(xlim=['2020-01-01','2021-09-01'],figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Can do same for ylim and add c para,eter for color 'green'
df_tesla['High'].plot(ylim=(0,1000),c='yellow',ls='--')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2017-03-02', '2017-03-03', '2017-03-06', '2017-03-07',
#                '2017-03-08', '2017-03-09', '2017-03-10', '2017-03-13',
#                '2017-03-14', '2017-03-15',
#                ...
#                '2022-02-15', '2022-02-16', '2022-02-17', '2022-02-18',
#                '2022-02-22', '2022-02-23', '2022-02-24', '2022-02-25',
#                '2022-02-28', '2022-03-01'],
#               dtype='datetime64[ns]', name='Date', length=1259, freq=None)

# %%
index = df_tesla.loc['2020-01-01':'2021-09-01'].index
df_tesla.iloc[:15,:2]
# Out:
#                  High        Low
# Date
# 2017-03-02  50.655998  49.653999
# 2017-03-03  50.380001  49.799999
# 2017-03-06  50.340000  49.501999
# 2017-03-07  50.778000  49.664001
# 2017-03-08  50.014000  49.063999
# 2017-03-09  49.731998  48.599998
# 2017-03-10  49.299999  48.599998
# 2017-03-13  49.369999  48.556000
# 2017-03-14  51.624001  49.203999
# 2017-03-15  52.200001  50.854000
# 2017-03-16  53.150002  51.812000
# 2017-03-17  53.066002  52.240002
# 2017-03-20  52.910000  51.764000
# 2017-03-21  52.959999  50.048000
# 2017-03-22  51.014000  50.102001

# %%
share_open = df_tesla.loc['2020-01-01':'2021-09-01']['Open']

# %%
share_open
# Out:
# Date
# 2020-01-02     84.900002
# 2020-01-03     88.099998
# 2020-01-06     88.094002
# 2020-01-07     92.279999
# 2020-01-08     94.739998
#                  ...
# 2021-08-26    708.309998
# 2021-08-27    705.000000
# 2021-08-30    714.719971
# 2021-08-31    733.000000
# 2021-09-01    734.080017
# Name: Open, Length: 421, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure,axis = plt.subplots()
figure.autofmt_xdate()
axis.plot(index,share_open)

# %%
df_tesla = df_tesla.reset_index()

# %%
df_tesla
# Out:
#       index       Date        High         Low        Open       Close  \
# 0         0 2017-03-02   50.655998   49.653999   49.942001   50.096001
# 1         1 2017-03-03   50.380001   49.799999   50.147999   50.313999
# 2         2 2017-03-06   50.340000   49.501999   49.582001   50.242001
# 3         3 2017-03-07   50.778000   49.664001   50.383999   49.717999
# 4         4 2017-03-08   50.014000   49.063999   49.400002   49.374001
# ...     ...        ...         ...         ...         ...         ...
# 1254   1254 2022-02-23  835.299988  760.559998  830.429993  764.039978
# 1255   1255 2022-02-24  802.479980  700.000000  700.390015  800.770020
# 1256   1256 2022-02-25  819.500000  782.400024  809.229980  809.869995
# 1257   1257 2022-02-28  876.859985  814.710022  815.010010  870.429993
# 1258   1258 2022-03-01  889.880005  856.695190  869.679993  869.219421
#
#           Volume   Adj Close
# 0     16759000.0   50.096001
# 1     14597000.0   50.313999
# ...

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      1259 non-null   int64
#  1   Date       1259 non-null   datetime64[ns]
#  2   High       1259 non-null   float64
#  3   Low        1259 non-null   float64
#  4   Open       1259 non-null   float64
#  5   Close      1259 non-null   float64
#  6   Volume     1259 non-null   float64
#  7   Adj Close  1259 non-null   float64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 78.8 KB

# %%
pd.to_datetime(df_tesla['Date'])
# Out:
# 0      2017-03-02
# 1      2017-03-03
# 2      2017-03-06
# 3      2017-03-07
# 4      2017-03-08
#           ...
# 1254   2022-02-23
# 1255   2022-02-24
# 1256   2022-02-25
# 1257   2022-02-28
# 1258   2022-03-01
# Name: Date, Length: 1259, dtype: datetime64[ns]

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      1259 non-null   int64
#  1   Date       1259 non-null   datetime64[ns]
#  2   High       1259 non-null   float64
#  3   Low        1259 non-null   float64
#  4   Open       1259 non-null   float64
#  5   Close      1259 non-null   float64
#  6   Volume     1259 non-null   float64
#  7   Adj Close  1259 non-null   float64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 78.8 KB

# %%
df_tesla
# Out:
#       index       Date        High         Low        Open       Close  \
# 0         0 2017-03-02   50.655998   49.653999   49.942001   50.096001
# 1         1 2017-03-03   50.380001   49.799999   50.147999   50.313999
# 2         2 2017-03-06   50.340000   49.501999   49.582001   50.242001
# 3         3 2017-03-07   50.778000   49.664001   50.383999   49.717999
# 4         4 2017-03-08   50.014000   49.063999   49.400002   49.374001
# ...     ...        ...         ...         ...         ...         ...
# 1254   1254 2022-02-23  835.299988  760.559998  830.429993  764.039978
# 1255   1255 2022-02-24  802.479980  700.000000  700.390015  800.770020
# 1256   1256 2022-02-25  819.500000  782.400024  809.229980  809.869995
# 1257   1257 2022-02-28  876.859985  814.710022  815.010010  870.429993
# 1258   1258 2022-03-01  889.880005  856.695190  869.679993  869.219421
#
#           Volume   Adj Close
# 0     16759000.0   50.096001
# 1     14597000.0   50.313999
# ...

# %%
df_tesla.set_index('Date',drop=True)
# Out:
#             index        High         Low        Open       Close      Volume  \
# Date
# 2017-03-02      0   50.655998   49.653999   49.942001   50.096001  16759000.0
# 2017-03-03      1   50.380001   49.799999   50.147999   50.313999  14597000.0
# 2017-03-06      2   50.340000   49.501999   49.582001   50.242001  16777500.0
# 2017-03-07      3   50.778000   49.664001   50.383999   49.717999  17297500.0
# 2017-03-08      4   50.014000   49.063999   49.400002   49.374001  18626000.0
# ...           ...         ...         ...         ...         ...         ...
# 2022-02-23   1254  835.299988  760.559998  830.429993  764.039978  31752300.0
# 2022-02-24   1255  802.479980  700.000000  700.390015  800.770020  45107400.0
# 2022-02-25   1256  819.500000  782.400024  809.229980  809.869995  25309500.0
# 2022-02-28   1257  876.859985  814.710022  815.010010  870.429993  32877700.0
# 2022-03-01   1258  889.880005  856.695190  869.679993  869.219421  16528666.0
#
#              Adj Close
# ...

# %%
df_tesla.reset_index()
# Out:
#       level_0  index       Date        High         Low        Open  \
# 0           0      0 2017-03-02   50.655998   49.653999   49.942001
# 1           1      1 2017-03-03   50.380001   49.799999   50.147999
# 2           2      2 2017-03-06   50.340000   49.501999   49.582001
# 3           3      3 2017-03-07   50.778000   49.664001   50.383999
# 4           4      4 2017-03-08   50.014000   49.063999   49.400002
# ...       ...    ...        ...         ...         ...         ...
# 1254     1254   1254 2022-02-23  835.299988  760.559998  830.429993
# 1255     1255   1255 2022-02-24  802.479980  700.000000  700.390015
# 1256     1256   1256 2022-02-25  819.500000  782.400024  809.229980
# 1257     1257   1257 2022-02-28  876.859985  814.710022  815.010010
# 1258     1258   1258 2022-03-01  889.880005  856.695190  869.679993
#
#            Close      Volume   Adj Close
# 0      50.096001  16759000.0   50.096001
# 1      50.313999  14597000.0   50.313999
# ...
